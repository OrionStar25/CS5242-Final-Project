# %%
import pandas as pd

# %%
file_path= '../data/cleaned_imdb.csv'
movies = pd.read_csv(file_path, index_col=0)
movies.head()
# Out:
#                     movie                     genre labelled_genre  \
# 0            Bullet Train    Action,Comedy,Thriller         Action
# 1              Black Adam  Action,Adventure,Fantasy         Action
# 2       Top Gun: Maverick              Action,Drama         Action
# 3          The Woman King      Action,Drama,History         Action
# 4  Thor: Love and Thunder   Action,Adventure,Comedy         Action
#
#   first_genre                                    stemmed_summary
# 0      Action  five assassin aboard swift move bullet train f...
# 1      Action  near year bestow almighti power egyptian god i...
# 2      Action  thirti year maverick still push envelop top na...
# 3      Action  histor epic inspir true event took place kingd...
# 4      Action  thor enlist help valkyri korg ex girlfriend ja...
