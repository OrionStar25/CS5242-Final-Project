# %%
#import libraries
import pandas as pd
import numpy as np
import json
import nltk
import re
import csv
import matplotlib.pyplot as plt 
import seaborn as sns
from tqdm import tqdm

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
file_path= 'data/labelled_imdb.csv'
movies = pd.read_csv(file_path)
movies.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                   movie                     genre  \
# 0             0           0            Bullet Train    Action,Comedy,Thriller
# 1             1           1              Black Adam  Action,Adventure,Fantasy
# 2             2           2       Top Gun: Maverick              Action,Drama
# 3             3           3          The Woman King      Action,Drama,History
# 4             4           4  Thor: Love and Thunder   Action,Adventure,Comedy
#
#                                              summary labelled_genre
# 0  Five assassins aboard a swiftly-moving bullet ...         Action
# 1  Nearly 5,000 years after he was bestowed with ...         Action
# 2  After thirty years, Maverick is still pushing ...         Action
# 3  A historical epic inspired by true events that...         Action
# 4  Thor enlists the help of Valkyrie, Korg and ex...         Action

# %%
unnamed_cols  =  movies.columns.str.contains('Unnamed')
movies = movies.drop(movies[movies.columns[unnamed_cols]], axis=1)

movies.head()
# Out:
#                     movie                     genre  \
# 0            Bullet Train    Action,Comedy,Thriller
# 1              Black Adam  Action,Adventure,Fantasy
# 2       Top Gun: Maverick              Action,Drama
# 3          The Woman King      Action,Drama,History
# 4  Thor: Love and Thunder   Action,Adventure,Comedy
#
#                                              summary labelled_genre
# 0  Five assassins aboard a swiftly-moving bullet ...         Action
# 1  Nearly 5,000 years after he was bestowed with ...         Action
# 2  After thirty years, Maverick is still pushing ...         Action
# 3  A historical epic inspired by true events that...         Action
# 4  Thor enlists the help of Valkyrie, Korg and ex...         Action

# %%
movies['first_genre'] = movies['genre'].str.split(',')
movies['first_genre'] = movies['first_genre'].apply(lambda x: x[0])
movies
# Out:
#                                         movie                     genre  \
# 0                                Bullet Train    Action,Comedy,Thriller
# 1                                  Black Adam  Action,Adventure,Fantasy
# 2                           Top Gun: Maverick              Action,Drama
# 3                              The Woman King      Action,Drama,History
# 4                      Thor: Love and Thunder   Action,Adventure,Comedy
# ...                                       ...                       ...
# 62614  Underland Episode III: Beyond the Rift   Action,Adventure,Comedy
# 62615         The Turtle and the Time Machine       Comedy,Drama,Sci-Fi
# 62616                           Form Function  Documentary,Short,Sci-Fi
# 62617                                   Forge       Drama,Family,Sci-Fi
# 62618                                 Paradox                    Sci-Fi
#
#                                                  summary labelled_genre  \
# 0      Five assassins aboard a swiftly-moving bullet ...         Action
# 1      Nearly 5,000 years after he was bestowed with ...         Action
# 2      After thirty years, Maverick is still pushing ...         Action
# 3      A historical epic inspired by true events that...         Action
# 4      Thor enlists the help of Valkyrie, Korg and ex...         Action
# ...                                                  ...            ...
# 62614  UNDERLAND' takes us along for the journey of a...         Sci-Fi
# 62615  Three 20-somethings roam the Tennessee country...         Sci-Fi
# 62616  This purely visual short film shows an industr...         Sci-Fi
# 62617  A man tries to save his reclusive scientist br...         Sci-Fi
# 62618                                         Add a Plot         Sci-Fi
#
#        first_genre
# 0           Action
# 1           Action
# 2           Action
# 3           Action
# 4           Action
# ...            ...
# 62614       Action
# 62615       Comedy
# 62616  Documentary
# 62617        Drama
# 62618       Sci-Fi
#
# [62619 rows x 5 columns]

# %%
movies=movies.drop_duplicates(subset='movie')
movies = movies[movies["summary"].str.contains("Add a Plot") == False]
movies = movies.reset_index(drop=True)
movies
# Out:
#                                         movie                     genre  \
# 0                                Bullet Train    Action,Comedy,Thriller
# 1                                  Black Adam  Action,Adventure,Fantasy
# 2                           Top Gun: Maverick              Action,Drama
# 3                              The Woman King      Action,Drama,History
# 4                      Thor: Love and Thunder   Action,Adventure,Comedy
# ...                                       ...                       ...
# 40170                         The EBay Pickup  Documentary,Short,Action
# 40171  Underland Episode III: Beyond the Rift   Action,Adventure,Comedy
# 40172         The Turtle and the Time Machine       Comedy,Drama,Sci-Fi
# 40173                           Form Function  Documentary,Short,Sci-Fi
# 40174                                   Forge       Drama,Family,Sci-Fi
#
#                                                  summary labelled_genre  \
# 0      Five assassins aboard a swiftly-moving bullet ...         Action
# 1      Nearly 5,000 years after he was bestowed with ...         Action
# 2      After thirty years, Maverick is still pushing ...         Action
# 3      A historical epic inspired by true events that...         Action
# 4      Thor enlists the help of Valkyrie, Korg and ex...         Action
# ...                                                  ...            ...
# 40170  After winning a bid on EBay, Pat travels far f...         Sci-Fi
# 40171  UNDERLAND' takes us along for the journey of a...         Sci-Fi
# 40172  Three 20-somethings roam the Tennessee country...         Sci-Fi
# 40173  This purely visual short film shows an industr...         Sci-Fi
# 40174  A man tries to save his reclusive scientist br...         Sci-Fi
#
#        first_genre
# 0           Action
# 1           Action
# 2           Action
# 3           Action
# 4           Action
# ...            ...
# 40170  Documentary
# 40171       Action
# 40172       Comedy
# 40173  Documentary
# 40174        Drama
#
# [40175 rows x 5 columns]

# %%
def clean_dataset(text):
    # remove backslash-apostrophe 
    text = re.sub("\'", "", text) 
    # remove everything except alphabets 
    text = re.sub("[^a-zA-Z]"," ",text) 
    # remove whitespaces 
    text = ' '.join(text.split()) 
    # convert text to lowercase 
    text = text.lower() 
    
    return text

# %%
movies['clean_summary'] = movies['summary'].apply(lambda x: clean_dataset(x))
movies.head(5)
# Out:
#                     movie                     genre  \
# 0            Bullet Train    Action,Comedy,Thriller
# 1              Black Adam  Action,Adventure,Fantasy
# 2       Top Gun: Maverick              Action,Drama
# 3          The Woman King      Action,Drama,History
# 4  Thor: Love and Thunder   Action,Adventure,Comedy
#
#                                              summary labelled_genre  \
# 0  Five assassins aboard a swiftly-moving bullet ...         Action
# 1  Nearly 5,000 years after he was bestowed with ...         Action
# 2  After thirty years, Maverick is still pushing ...         Action
# 3  A historical epic inspired by true events that...         Action
# 4  Thor enlists the help of Valkyrie, Korg and ex...         Action
#
#   first_genre                                      clean_summary
# 0      Action  five assassins aboard a swiftly moving bullet ...
# 1      Action  nearly years after he was bestowed with the al...
# 2      Action  after thirty years maverick is still pushing t...
# 3      Action  a historical epic inspired by true events that...
# 4      Action  thor enlists the help of valkyrie korg and ex ...

# %%
del movies['summary']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/niharika/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)

movies['clean_summary'] = movies['clean_summary'].apply(lambda x: remove_stopwords(x))
movies.head(5)
# Out:
#                     movie                     genre labelled_genre  \
# 0            Bullet Train    Action,Comedy,Thriller         Action
# 1              Black Adam  Action,Adventure,Fantasy         Action
# 2       Top Gun: Maverick              Action,Drama         Action
# 3          The Woman King      Action,Drama,History         Action
# 4  Thor: Love and Thunder   Action,Adventure,Comedy         Action
#
#   first_genre                                      clean_summary
# 0      Action  five assassins aboard swiftly moving bullet tr...
# 1      Action  nearly years bestowed almighty powers egyptian...
# 2      Action  thirty years maverick still pushing envelope t...
# 3      Action  historical epic inspired true events took plac...
# 4      Action  thor enlists help valkyrie korg ex girlfriend ...

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

movies['stemmed_summary'] = movies['clean_summary'].str.split()
movies['stemmed_summary'] = movies['stemmed_summary'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.
movies['stemmed_summary'] = movies['stemmed_summary'].apply(lambda x: ' '.join(x))
movies
# Out:
#                                         movie                     genre  \
# 0                                Bullet Train    Action,Comedy,Thriller
# 1                                  Black Adam  Action,Adventure,Fantasy
# 2                           Top Gun: Maverick              Action,Drama
# 3                              The Woman King      Action,Drama,History
# 4                      Thor: Love and Thunder   Action,Adventure,Comedy
# ...                                       ...                       ...
# 40170                         The EBay Pickup  Documentary,Short,Action
# 40171  Underland Episode III: Beyond the Rift   Action,Adventure,Comedy
# 40172         The Turtle and the Time Machine       Comedy,Drama,Sci-Fi
# 40173                           Form Function  Documentary,Short,Sci-Fi
# 40174                                   Forge       Drama,Family,Sci-Fi
#
#       labelled_genre  first_genre  \
# 0             Action       Action
# 1             Action       Action
# 2             Action       Action
# 3             Action       Action
# 4             Action       Action
# ...              ...          ...
# 40170         Sci-Fi  Documentary
# 40171         Sci-Fi       Action
# 40172         Sci-Fi       Comedy
# 40173         Sci-Fi  Documentary
# 40174         Sci-Fi        Drama
#
#                                            clean_summary  \
# 0      five assassins aboard swiftly moving bullet tr...
# 1      nearly years bestowed almighty powers egyptian...
# 2      thirty years maverick still pushing envelope t...
# 3      historical epic inspired true events took plac...
# 4      thor enlists help valkyrie korg ex girlfriend ...
# ...                                                  ...
# 40170  winning bid ebay pat travels far home pick unu...
# 40171  underland takes us along journey young girl th...
# 40172  three somethings roam tennessee countryside se...
# 40173  purely visual short film shows industrial desi...
# 40174  man tries save reclusive scientist brother sli...
#
#                                          stemmed_summary
# 0      five assassin aboard swift move bullet train f...
# 1      near year bestow almighti power egyptian god i...
# 2      thirti year maverick still push envelop top na...
# 3      histor epic inspir true event took place kingd...
# 4      thor enlist help valkyri korg ex girlfriend ja...
# ...                                                  ...
# 40170  win bid ebay pat travel far home pick unusu it...
# 40171  underland take us along journey young girl thr...
# 40172  three someth roam tennesse countrysid search t...
# 40173  pure visual short film show industri design cr...
# 40174  man tri save reclus scientist brother slip per...
#
# [40175 rows x 6 columns]

# %%
del movies['clean_summary']
movies
# Out:
#                                         movie                     genre  \
# 0                                Bullet Train    Action,Comedy,Thriller
# 1                                  Black Adam  Action,Adventure,Fantasy
# 2                           Top Gun: Maverick              Action,Drama
# 3                              The Woman King      Action,Drama,History
# 4                      Thor: Love and Thunder   Action,Adventure,Comedy
# ...                                       ...                       ...
# 40170                         The EBay Pickup  Documentary,Short,Action
# 40171  Underland Episode III: Beyond the Rift   Action,Adventure,Comedy
# 40172         The Turtle and the Time Machine       Comedy,Drama,Sci-Fi
# 40173                           Form Function  Documentary,Short,Sci-Fi
# 40174                                   Forge       Drama,Family,Sci-Fi
#
#       labelled_genre  first_genre  \
# 0             Action       Action
# 1             Action       Action
# 2             Action       Action
# 3             Action       Action
# 4             Action       Action
# ...              ...          ...
# 40170         Sci-Fi  Documentary
# 40171         Sci-Fi       Action
# 40172         Sci-Fi       Comedy
# 40173         Sci-Fi  Documentary
# 40174         Sci-Fi        Drama
#
#                                          stemmed_summary
# 0      five assassin aboard swift move bullet train f...
# 1      near year bestow almighti power egyptian god i...
# 2      thirti year maverick still push envelop top na...
# 3      histor epic inspir true event took place kingd...
# 4      thor enlist help valkyri korg ex girlfriend ja...
# ...                                                  ...
# 40170  win bid ebay pat travel far home pick unusu it...
# 40171  underland take us along journey young girl thr...
# 40172  three someth roam tennesse countrysid search t...
# 40173  pure visual short film show industri design cr...
# 40174  man tri save reclus scientist brother slip per...
#
# [40175 rows x 5 columns]

# %%
movies.to_csv('data/cleaned_imdb.csv')

# %%
# Visualize no of movies per genre

# Decide based on visualization if more data of a specific genre is needed
# which column of genre to be used

# Length of summaries
