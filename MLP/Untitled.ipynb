# %%
import pandas as pd

# %%
mov = pd.read_csv('../data/train_imdb.csv', index_col=0)

# %%
mov.head()
# Out:
#                movie                    genre labelled_genre first_genre  \
# 0   Flaming Brothers     Action,Crime,Romance         Action      Action
# 1           Uchronia            Drama,Fantasy        Fantasy       Drama
# 2  Button for Dreams                Animation      Animation   Animation
# 3        Girlfriends             Comedy,Drama         Comedy      Comedy
# 4    Hangman's Noose  Mystery,Sci-Fi,Thriller         Sci-Fi     Mystery
#
#                                              summary
# 0  tale two brother one left triad gone legit dec...
# 1  earth enabl alien layla majnun becom human fin...
# 2  like everi night littl oggi lie cot grandfath ...
# 3  photograph girlfriend roommat stuck small chan...
# 4  stori man taken time foreign scienc becom hybr...

# %%
import math
cutoff = math.floor(len(mov)*0.8)

# %%
print(cutoff)
# Out:
# 16675

# %%
mov[:cutoff]
# Out:
#                           movie                    genre labelled_genre  \
# 0              Flaming Brothers     Action,Crime,Romance         Action
# 1                      Uchronia            Drama,Fantasy        Fantasy
# 2             Button for Dreams                Animation      Animation
# 3                   Girlfriends             Comedy,Drama         Comedy
# 4               Hangman's Noose  Mystery,Sci-Fi,Thriller         Sci-Fi
# ...                         ...                      ...            ...
# 16670  Most Dangerous Man Alive                   Sci-Fi         Sci-Fi
# 16671                  Crawlers                   Horror         Horror
# 16672                  Red Girl   Fantasy,Mystery,Sci-Fi        Fantasy
# 16673    The Mandalorian Legacy                   Sci-Fi         Sci-Fi
# 16674                  Echo Dr.      Action,Drama,Sci-Fi         Sci-Fi
#
#       first_genre                                            summary
# ...

# %%
mov[cutoff:]
# Out:
#                                       movie                        genre  \
# 16675                           The Shimian                       Horror
# 16676                   The Wedding Weekend           Comedy,Drama,Music
# 16677         Ali Baba and the Seven Dwarfs          Action,Comedy,Drama
# 16678                     Dinosaurs at Dusk  Documentary,Short,Adventure
# 16679               Horseplay: Jungle-Mania  Documentary,Animation,Short
# ...                                     ...                          ...
# 20839                      Sentinel 2099 SE                       Sci-Fi
# 20840  Society of Explorers and Adventurers                    Adventure
# 20841               Origins IV: Revelations       Action,Adventure,Drama
# 20842                        The Death Kiss           Comedy,Crime,Drama
# 20843                              Oddballs                       Comedy
#
#       labelled_genre  first_genre  \
# 16675         Horror       Horror
# ...

# %%
test = pd.read_csv('../data/test_imdb.csv', index_col=1)

# %%
test.groupby('labelled_genre').size()
# Out:
# labelled_genre
# Action       816
# Adventure    813
# Animation    636
# Comedy       756
# Fantasy      667
# Horror       828
# Sci-Fi       695
# dtype: int64
